# %%
# setting up Pretty Printing
from sympy import init_printing
init_printing()

# %%
from sympy import *
x, y, z, a, b = symbols('x y z a b')

# %%
Integral(sqrt(1/x), x)
# Out:
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡
